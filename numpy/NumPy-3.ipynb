# %% [raw]
# DOT PRODUCT

# %%
import numpy as np

# %%
import random

# %%
np.random.seed(0)

# %%
mat1 = np.random.randint(10, size=(5,3))
mat1
# Out:
# array([[5, 0, 3],
#        [3, 7, 9],
#        [3, 5, 2],
#        [4, 7, 6],
#        [8, 8, 1]])

# %%
mat2 = np.random.randint(10, size=(5,3))
mat2
# Out:
# array([[6, 7, 7],
#        [8, 1, 5],
#        [9, 8, 9],
#        [4, 3, 0],
#        [3, 5, 0]])

# %%
mat2
# Out:
# array([[6, 7, 7],
#        [8, 1, 5],
#        [9, 8, 9],
#        [4, 3, 0],
#        [3, 5, 0]])

# %%
mat1.shape, mat2.shape
# Out:
# ((5, 3), (5, 3))

# %%
mat1 * mat2 # Element wise multiplication (Hadamard product)
# Out:
# array([[30,  0, 21],
#        [24,  7, 45],
#        [27, 40, 18],
#        [16, 21,  0],
#        [24, 40,  0]])

# %%
# Dot product
np.dot(mat1,mat2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Dot product
# ----> 2 np.dot(mat1,mat2)
#
# ValueError: shapes (5,3) and (5,3) not aligned: 3 (dim 1) != 5 (dim 0)

# %%
# Transpose mat1
mat1.T
# Out:
# array([[5, 3, 3, 4, 8],
#        [0, 7, 5, 7, 8],
#        [3, 9, 2, 6, 1]])

# %%
mat1.T.shape, mat2.shape
# Out:
# ((3, 5), (5, 3))

# %%
mat3 = np.dot(mat1,mat2.T)

# %%
mat3
# Out:
# array([[ 51,  55,  72,  20,  15],
#        [130,  76, 164,  33,  44],
#        [ 67,  39,  85,  27,  34],
#        [115,  69, 146,  37,  47],
#        [111,  77, 145,  56,  64]])

# %%
mat3.shape
# Out:
# (5, 5)

# %%
np.dot(mat1.T,mat2)
# Out:
# array([[121, 114,  77],
#        [153, 108,  80],
#        [135,  69,  84]])

# %%
mat1.shape,mat2.shape
# Out:
# ((5, 3), (5, 3))

# %%
## Dot product example

# %%
np.random.seed(0)

# %%
sales_amount = np.random.randint(20, size=(5,3))

# %%
sales_amount
# Out:
# array([[ 2,  2,  9],
#        [ 1,  2,  9],
#        [15,  9, 14],
#        [16,  3,  8],
#        [11, 18, 12]])

# %%
# Creates weekly_sales dataframe
import pandas as pd

weekly_sales = pd.DataFrame(sales_amount, index=['mon','Tue','Wed','Thu','Fri'],
                           columns = ['Almond butter','Peanut butter','Cashew butter'])

# %%
weekly_sales
# Out:
#      Almond butter  Peanut butter  Cashew butter
# mon              2              2              9
# Tue              1              2              9
# Wed             15              9             14
# Thu             16              3              8
# Fri             11             18             12

# %%
# Create prices array
prices = np.array([10,8,12])

# %%
prices
# Out:
# array([10,  8, 12])

# %%
# Create butter_prices dataframe
butter_prices = pd.DataFrame(prices.reshape(1,3), index=['Price'],columns=['Almond butter','Peanut butter','Cashew butter'])
butter_prices
# Out:
#        Almond butter  Peanut butter  Cashew butter
# Price             10              8             12

# %%
prices
# Out:
# array([10,  8, 12])

# %%
total_sales = prices.dot(sales_amount)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 total_sales = prices.dot(sales_amount)
#
# ValueError: shapes (3,) and (5,3) not aligned: 3 (dim 0) != 5 (dim 0)

# %%
# Shape aren't alligned, lets transpose
total_sales = prices.dot(sales_amount.T)

# %%
total_sales
# Out:
# array([144, 134, 390, 280, 398])

# %%
# Create daily sales
butter_prices.shape
# Out:
# (1, 3)

# %%
weekly_sales.shape
# Out:
# (5, 3)

# %%
daily_sales = butter_prices.dot(weekly_sales.T)

# %%
daily_sales
# Out:
#        mon  Tue  Wed  Thu  Fri
# Price  144  134  390  280  398

# %%
weekly_sales
# Out:
#      Almond butter  Peanut butter  Cashew butter
# mon              2              2              9
# Tue              1              2              9
# Wed             15              9             14
# Thu             16              3              8
# Fri             11             18             12

# %%
# Dosent work, not the right shape
weekly_sales["Total ($)"] = daily_sales
weekly_sales
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 weekly_sales["Total ($)"] = daily_sales
#       2 weekly_sales
#
# File /usr/lib/python3.14/site-packages/pandas/core/frame.py:4312, in DataFrame.__setitem__(self, key, value)
#    4308             self._setitem_frame(key, value)
#    4309         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4310             self._setitem_array(key, value)
#    4311         elif isinstance(value, DataFrame):
# -> 4312             self._set_item_frame_value(key, value)
#    4313         elif (
#    4314             is_list_like(value)
#    4315             and not self.columns.is_unique
#
# File /usr/lib/python3.14/site-packages/pandas/core/frame.py:4470, in DataFrame._set_item_frame_value(self, key, value)
#    4466
#    4467             return self.isetitem(locs, value)
#    4468
# ...

# %%
weekly_sales["Total ($)"] = daily_sales.T

# %%
weekly_sales
# Out:
#      Almond butter  Peanut butter  Cashew butter  Total ($)
# mon              2              2              9        144
# Tue              1              2              9        134
# Wed             15              9             14        390
# Thu             16              3              8        280
# Fri             11             18             12        398

# %% [raw]
# Comparison operators

# %%
a1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 a1
#
# NameError: name 'a1' is not defined

# %%
a1 = np.random.randint(10,size=(1,3))

# %%
a1
# Out:
# array([[9, 2, 4]])

# %%
a2 = np.random.randint(10,size=(2,3))

# %%
a2
# Out:
# array([[4, 3, 3],
#        [0, 1, 5]])

# %%
a2 > a1
# Out:
# array([[False,  True, False],
#        [False, False,  True]])

# %%
a1 > a2
# Out:
# array([[ True, False,  True],
#        [ True,  True, False]])

# %%
a1 >= a2
# Out:
# array([[ True, False,  True],
#        [ True,  True, False]])

# %%
type(a1 >= a2), (a1>a2).dtype
# Out:
# (numpy.ndarray, dtype('bool'))

# %%
a1 < 10
# Out:
# array([[ True,  True,  True]])

# %%
a1<1
# Out:
# array([[False, False, False]])

# %%
a2<3
# Out:
# array([[False, False, False],
#        [ True,  True, False]])

# %%
a2
# Out:
# array([[4, 3, 3],
#        [0, 1, 5]])

# %%
 a1 == a2
# Out:
# array([[False, False, False],
#        [False, False, False]])

# %%
a1 == a1
# Out:
# array([[ True,  True,  True]])

# %%
a2
# Out:
# array([[4, 3, 3],
#        [0, 1, 5]])

# %%
a1 != a2
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True]])

# %%
a2 / 2
# Out:
# array([[2. , 1.5, 1.5],
#        [0. , 0.5, 2.5]])

# %%
a2 % 2
# Out:
# array([[0, 1, 1],
#        [0, 1, 1]])

# %%
a2 % 3
# Out:
# array([[1, 0, 0],
#        [0, 1, 2]])

# %%
a2 % 1
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
a2 ** 3
# Out:
# array([[ 64,  27,  27],
#        [  0,   1, 125]])

# %%
a2
# Out:
# array([[4, 3, 3],
#        [0, 1, 5]])

# %% [raw]
# 5. Sorting arrays

# %%
random_array = np.random.randint(10,size=(3,5))
random_array
# Out:
# array([[7, 1, 6, 0, 3],
#        [9, 4, 9, 0, 1],
#        [0, 8, 3, 5, 7]])

# %%
random_array.shape
# Out:
# (3, 5)

# %%
np.sort(random_array)
# Out:
# array([[0, 1, 3, 6, 7],
#        [0, 1, 4, 9, 9],
#        [0, 3, 5, 7, 8]])

# %%
np.argsort(random_array)
# Out:
# array([[3, 1, 4, 2, 0],
#        [3, 4, 1, 0, 2],
#        [0, 2, 3, 4, 1]])

# %%
np.argsort(a1)
# Out:
# array([[1, 2, 0]])

# %%
a1
# Out:
# array([[9, 2, 4]])

# %%
np.argmin(a1)
# Out:
# np.int64(1)

# %%
np.argmax(a2)
# Out:
# np.int64(5)

# %%
a2
# Out:
# array([[4, 3, 3],
#        [0, 1, 5]])

# %%
a3 = np.random.randint(10,size=(3,5))

# %%
a3
# Out:
# array([[8, 3, 2, 0, 8],
#        [8, 4, 3, 6, 4],
#        [4, 1, 5, 6, 2]])

# %%
np.argmax(a3,axis=0)
# Out:
# array([0, 1, 2, 1, 0])

# %%
np.argmax(a3,axis=1)
# Out:
# array([0, 0, 3])

# %%
d = np.random.randint(10,size=(2,3,5))
d
# Out:
# array([[[8, 9, 5, 9, 1],
#         [1, 0, 0, 9, 0],
#         [1, 0, 9, 9, 8]],
#
#        [[8, 5, 1, 1, 3],
#         [0, 0, 3, 6, 3],
#         [0, 0, 4, 4, 6]]])

# %%
np.argmax(d,axis=0)
# Out:
# array([[0, 0, 0, 0, 1],
#        [0, 0, 1, 0, 1],
#        [0, 0, 0, 0, 0]])

# %%
np.argmax(d,axis=1)
# Out:
# array([[0, 0, 2, 0, 2],
#        [0, 0, 2, 1, 2]])

# %%
np.argmax(d,axis=2)
# Out:
# array([[1, 3, 2],
#        [0, 3, 4]])

# %%
np.argmax(np.random.randint(10,size=(2,3,5)),axis=0)
# Out:
# array([[1, 0, 1, 0, 0],
#        [0, 1, 0, 1, 0],
#        [0, 1, 0, 0, 0]])
